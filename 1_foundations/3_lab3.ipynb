# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/cv.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Stanislav  Aituhanov
#
#        Home  Address:  Ukraine,  Kyiv,  Salutna  2b,  Citizenship:  Ukraine  E-mail:  aytuganov@gmail.com  Phone:  +38(0)  0990502860  https://www.linkedin.com/in/aytuganov/
# Objective
# Frontend  (React)  /  Full  Stack  (React  /  Node.js  /  Go)  Senior  Developer  /  Backend  Developer
# (Node.js
#
# /
#
# Go)
#
# Skills  &  Tech  stack
# ●  JS  Front-End  and  Back-End  Development  (over  7  years)  ●  JavaScript  Fundamentals  and  Hard  Parts:  Asynchronous  JS,  Functional  patterns,
# OOP
#
# in
#
# JS
#  ●  Frontend:  React,  Next.js,  Tailwind  CSS,  Material  UI  (MUI),  SASS,  Vite  ●  Testing  &  Quality:  TDD,  Vitest,  React  Testing  Library  ●  Backend:  Node.js,  Express.js,  Fastify,  Go  ●  Data  &  Storage:  MongoDB,  PostgreSQL  ●  Messaging  &  Streaming:  Kafka  ●  APIs  &  Real-time:  REST,  GraphQL,  WebSockets  ●  Architecture  &  Design:  Microservices,  Database  design  ●  Web  Platform:  Web  Performance,  Web  Security,  Web  Storage  (IndexedDB,
# localStorage,
#
# Cache
#
# API)
#  ●  DevOps  &  CI/CD:  Docker,  Kubernetes,  AWS,  GCP,  GitHub  Actions,  CI/CD  pipelines,
# Doppler
#
# (secrets)
#  ●  Infrastructure  as  Code:  Terraform,  Pulumi  ●  AI-Assisted  Dev:  Cursor,  Claude  Code,  MCP  ●  Version  Control  &  Collaboration:  Git,  GitLab  ●  Legacy/Other:  AngularJS  /  Angular  2+  (last  used  5+  years  ago)
#
#
#
# Professional  Experience
# Senior  Full  Stack  (React,  Node.js,  Go)  Developer  MMD  Smart  Kyiv,  Remote  December  2022  –  Present  •  Building  Enterprise  Platform  for  the  company's  clients  and  vendors  from  scratch.  •  Creating  UI  interfaces,  components  library,  API  integrations  •  Responsible  for  React  Performance  •  Building  microservices  in  Node.js  &  Go  •  Responsible  for  microservices  architecture.  •  Designed  and  implemented  database  structures.  Technical  stack:  React18,  Storybook,  Tailwind  CSS,  Node.js,  Golang,  Kafka,  Docker,
# Kubernetes,
#
# Redis,
#
# Mongodb,
#
# Postgresql
#
# Senior  React/Node.js  Developer  Sphere  Solutions  Kyiv,  Remote
#  February  2021  –  December  2022  Technical  stack:  React16,  Tailwind,  Node.js,  Mongodb   •  Developed  back  office  portal  and  several  front  office  projects  for  a  British
# multinational
#
# oil
#
# and
#
# gas
#
# company
#
# from
#
# scratch.
#  •  Built  micro  frontends  architecture  and  set  up  submodules  for  the  back  office  portal.  •  Developed  custom  components  and  screens,  integrated  APIs,  and  created  complex,
# multistep
#
# wizards.
#  •  Communicated  and  resolved  issues  with  design  and  backend  teams.  •  Developed  an  internal  project  (Automated  Invoicing  system)  from  scratch.
# Senior  Fullstack   Developer  Luxoft  Kyiv  Ukraine  September  2020  –  February  2021  Technical  stack:  React16,  MaterialUI,  Node.js,  Mongodb   •  Developed  an  internal  user  portal  for  LG  to  create,  maintain,  and  run  mobile  phone
# application
#
# updates.
#  •  Integrated  new  React  features  such  as  hooks,  selectors,  and  functional  components
# architecture.
#
# Senior  Front-End  Developer  Luxoft  Stuttgart,  Germany  July  2019  –  August  2020  Technical  stack:  Angular2+,  React,  MaterialUI,  Node.js   •  Developed  and  supported  a  user  portal  for  one  of  the  top  car  brands.   •  Created  new  components  for  the  library  shared  with  other  Porsche  Portal  subprojects.   •  Implemented  solutions  for  integration  between  Access  ID  and  other  portal  services.   •  Supported  and  extended  E2E  tests,  participated  in  sprint  demos,  refinements,
# planning
#
# sessions,
#
# and
#
# architecture
#
# discussions.
#  Senior  React/Node.js  Developer  Luxoft  Kyiv,  Ukraine  October  2018  –  June  2019   •  Developed  the  Connected  Catalog  for  BMW  corporation,  allowing  partners  to  create  car
# configurations.
#   •  Integrated  new  technologies  and  approaches  to  building  web  applications,  added  new
# features,
#
# and
#
# ensured
#
# high-quality
#
# project
#
# completion.
#
# Senior  React/Node.js  Developer  Zoomdata,  Kyiv,  Ukraine  April  2018  –  October  2018   •  Rewrote  simple  parts  of  a  complex  project  originally  written  in  Backbone  to  React
# components.
#   •  Proposed  new  approaches  to  module  division  and  layer  architecture.   •  Participated  in  creating  a  new  version  of  the  project’s  CLI  tool,  including
# documentation
#
# and
#
# migration
#
# guide.
#   •  Conducted  demos  and  participated  in  discussions  with  the  product  owner  and  technical
# writer.
#   •  Developed  unit  tests,  CI/CD  processes,  and  utilized  advanced  Git  features.
# Full  Stack  Senior  Developer  (React,  Angular,  Angular2+,  Java)  EPAM  Systems,  Kyiv,  Ukraine  September  2014  –  April  2018   •  Full  Stack  (mostly  front  end)  senior  developer  for  various  projects,  including  a  custom
# assets
#
# report
#
# system
#
# for
#
# a
#
# global
#
# financial
#
# company.
#   •  Developed  front-end  application  architecture  and  visual  components.   •  Worked  on  requirements  with  business  analysts,  deployed  applications,  and  performed
# code
#
# refactoring.
#   •  Migrated  applications  from  Flex  to  AngularJS  and  Angular2+.   •  Developed  a  logistics  UI  project  using  ReactJS  and  integrated  backend  data  using
# sockets.
#
# Senior  Adobe  Flex  Developer,  Java  Developer  EPAM  Systems,  Kyiv,  Ukraine  September  2008  –  August  2014   •  Developed  an  internal  application  for  managing  clients’  accounts,  institutions,  and
# rebalances
#
# mechanisms
#
# for
#
# a
#
# major
#
# financial
#
# corporation.
#
# High  Education:
#   National  Aviation  University,  Engineer  Degree,  Software  for  Automated  Systems,
# 2006
#
# -
#
# 2011
#
# National
#
# University
#
# of
#
# Management,
#
# Magister
#
# in
#
# Marketing,
#
# 1993
#
# -
#
# 1999

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Stan Aituhanov"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Stan Aituhanov. You are answering questions on Stan Aituhanov's website, particularly questions related to Stan Aituhanov's career, background, skills and experience. Your responsibility is to represent Stan Aituhanov for interactions on the website as faithfully as possible. You are given a summary of Stan Aituhanov's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nStanislav Aituhanov is a senior full-stack software developer with over 15 years of commercial experience and more than 7 years working extensively with JavaScript across frontend and backend systems. He specializes in building complex, high-performance web applications using React, Node.js, and Go, with strong expertise in microservices architecture, cloud infrastructure, and modern DevOps practices.\n\nStanislav has led and contributed to enterprise-grade platforms for international clients in industries such as automotive, finance, energy, and analytics. He is experienced in designing scalable frontend architectures, building reusable component libraries, optimizing React performance, and implementing backend services with Node.js and Go. His technical background includes cloud-native development with Docker, Kubernetes, AWS, and GCP, as well as event-driven systems using Kafka.\n\nWith a strong engineering mindset, he values clean architecture, testing, and maintainability, and actively adopts AI-assisted development tools to improve productivity. Stanislav combines deep technical expertise with the ability to work closely with product, design, and backend teams, making him effective in both senior individual contributor and architectural roles.\n\n## LinkedIn Profile:\n \nStanislav  Aituhanov \n \n       Home  Address:  Ukraine,  Kyiv,  Salutna  2b,  Citizenship:  Ukraine  E-mail:  aytuganov@gmail.com  Phone:  +38(0)  0990502860  https://www.linkedin.com/in/aytuganov/  \nObjective  \nFrontend  (React)  /  Full  Stack  (React  /  Node.js  /  Go)  Senior  Developer  /  Backend  Developer  \n(Node.js\n \n/\n \nGo)\n \nSkills  &  Tech  stack   \n●  JS  Front-End  and  Back-End  Development  (over  7  years)  ●  JavaScript  Fundamentals  and  Hard  Parts:  Asynchronous  JS,  Functional  patterns,  \nOOP\n \nin\n \nJS\n ●  Frontend:  React,  Next.js,  Tailwind  CSS,  Material  UI  (MUI),  SASS,  Vite  ●  Testing  &  Quality:  TDD,  Vitest,  React  Testing  Library  ●  Backend:  Node.js,  Express.js,  Fastify,  Go  ●  Data  &  Storage:  MongoDB,  PostgreSQL  ●  Messaging  &  Streaming:  Kafka  ●  APIs  &  Real-time:  REST,  GraphQL,  WebSockets  ●  Architecture  &  Design:  Microservices,  Database  design  ●  Web  Platform:  Web  Performance,  Web  Security,  Web  Storage  (IndexedDB,  \nlocalStorage,\n \nCache\n \nAPI)\n ●  DevOps  &  CI/CD:  Docker,  Kubernetes,  AWS,  GCP,  GitHub  Actions,  CI/CD  pipelines,  \nDoppler\n \n(secrets)\n ●  Infrastructure  as  Code:  Terraform,  Pulumi  ●  AI-Assisted  Dev:  Cursor,  Claude  Code,  MCP  ●  Version  Control  &  Collaboration:  Git,  GitLab  ●  Legacy/Other:  AngularJS  /  Angular  2+  (last  used  5+  years  ago)  \n \n  \n \nProfessional  Experience  \nSenior  Full  Stack  (React,  Node.js,  Go)  Developer  MMD  Smart  Kyiv,  Remote  December  2022  –  Present  •  Building  Enterprise  Platform  for  the  company's  clients  and  vendors  from  scratch.  •  Creating  UI  interfaces,  components  library,  API  integrations  •  Responsible  for  React  Performance  •  Building  microservices  in  Node.js  &  Go  •  Responsible  for  microservices  architecture.  •  Designed  and  implemented  database  structures.  Technical  stack:  React18,  Storybook,  Tailwind  CSS,  Node.js,  Golang,  Kafka,  Docker,  \nKubernetes,\n \nRedis,\n \nMongodb,\n \nPostgresql\n \nSenior  React/Node.js  Developer  Sphere  Soluti ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply

# %%
evaluate(reply, "do you hold a patent?", messages[:1])

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
